# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="123456",
    database="testdb"   # same DB of Workbench
)
print(conn)
print("Connected successfully!")
cursor = conn.cursor()  #Act as a pointer
cursor.execute("Show Databases")
for x in cursor:
    print(x)
# Out:
# ...
# Connected successfully!
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('testdb',)
# ('testdb2',)
