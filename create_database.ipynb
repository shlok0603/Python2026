# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="123456",
    database="testdb"   # same DB of Workbench
)
cursor = conn.cursor()
cursor.execute("CREATE DATABASE if not exists testdb2")
conn.close()

# %%
import mysql.connector

new = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "123456",
    database = "testdb3"
)
curs = new.cursor()
curs.execute("CREATE DATABASE if not exists testdb3")
new.close()

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="123456",
    database="testdb3"   # same DB of Workbench
)
cursor = conn.cursor()
cursor.execute("CREATE TABLE if not exists testdb3.test_table_new(c1 INT, c2 VARCHAR(50), c3 FLOAT, c4 INT, c5 VARCHAR(30))")
conn.close()
